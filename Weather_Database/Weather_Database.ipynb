# %%
# Import dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import requests
import time
from datetime import datetime
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-90.000, high=90.000, size=2000)
lat_lngs = zip(lats,lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
# Create a new list to hold the cities
cities = []

# %%
# Identify the nearest city for each lat/lng combo
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, add it to the cities list
    if city not in cities:
        cities.append(city)
        
# Confirm length of city list
len(cities)
# Out:
# 775

# %%
# Import weather API key
from config import weather_api

# %%
# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api

# %%
# Create an empty list to hold weather data
city_data = []

# Print the beginning of logging
print("Beginning Data Retrieval")
print("------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in the list
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 because we're cheap
    if (i %50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
    
    #Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count
    record_count +=1
    
# Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_desc = city_weather["weather"][0]["description"]
        # Append the city information into city_data list
        city_data.append({"City": city.title(),
                          "Country" : city_country,
                         "Lat" : city_lat,
                         "Lng" : city_lng,
                         "Max Temp" : city_max_temp,
                         "Humidity" : city_humidity,
                         "Cloudiness":city_clouds,
                         "Wind Speed" : city_wind,
                         "Description" : city_desc})
                         
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
    
# Indicate that data loading is complete
print("-----------------------")
print("Data Retrieval Complete")
print("-----------------------")
# Out:
# Beginning Data Retrieval
# ------------------------
# Processing Record 1 of Set 1 | vardo
# Processing Record 2 of Set 1 | torbay
# Processing Record 3 of Set 1 | saint-philippe
# Processing Record 4 of Set 1 | pachino
# Processing Record 5 of Set 1 | vila franca do campo
# Processing Record 6 of Set 1 | saldanha
# Processing Record 7 of Set 1 | hermanus
# Processing Record 8 of Set 1 | papayal
# Processing Record 9 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 10 of Set 1 | sayat
# Processing Record 11 of Set 1 | myre
# Processing Record 12 of Set 1 | hunza
# City not found. Skipping...
# Processing Record 13 of Set 1 | ilulissat
# Processing Record 14 of Set 1 | victoria
# Processing Record 15 of Set 1 | castro
# Processing Record 16 of Set 1 | granja
# Processing Record 17 of Set 1 | oranjestad
# Processing Record 18 of Set 1 | yarmouth
# Processing Record 19 of Set 1 | port elizabeth
# Processing Record 20 of Set 1 | san cristobal
# Processing Record 21 of Set 1 | la asuncion
# Processing Record 22 of Set 1 | honningsvag
# Processing Record 23 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 24 of Set 1 | ushuaia
# Processing Record 25 of Set 1 | la tuque
# Processing Record 26 of Set 1 | bathurst
# Processing Record 27 of Set 1 | iqaluit
# Processing Record 28 of Set 1 | rocha
# Processing Record 29 of Set 1 | havoysund
# Processing Record 30 of Set 1 | ous
# Processing Record 31 of Set 1 | busselton
# Processing Record 32 of Set 1 | lardos
# Processing Record 33 of Set 1 | vestmanna
# Processing Record 34 of Set 1 | georgetown
# Processing Record 35 of Set 1 | bahir dar
# Processing Record 36 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 37 of Set 1 | cidreira
# Processing Record 38 of Set 1 | strangnas
# Processing Record 39 of Set 1 | grand gaube
# Processing Record 40 of Set 1 | souillac
# Processing Record 41 of Set 1 | coquimbo
# Processing Record 42 of Set 1 | druzhba
# Processing Record 43 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 44 of Set 1 | zhanakorgan
# Processing Record 45 of Set 1 | saint-louis
# Processing Record 46 of Set 1 | mahebourg
# Processing Record 47 of Set 1 | inhambane
# Processing Record 48 of Set 1 | balkhash
# Processing Record 49 of Set 1 | jamestown
# Processing Record 50 of Set 1 | lagoa
# Processing Record 1 of Set 2 | cape town
# Processing Record 2 of Set 2 | roald
# Processing Record 3 of Set 2 | elliot lake
# Processing Record 4 of Set 2 | chuy
# Processing Record 5 of Set 2 | caraballeda
# Processing Record 6 of Set 2 | capelinha
# Processing Record 7 of Set 2 | dikson
# Processing Record 8 of Set 2 | ponta do sol
# Processing Record 9 of Set 2 | klaksvik
# Processing Record 10 of Set 2 | arraial do cabo
# Processing Record 11 of Set 2 | nanortalik
# Processing Record 12 of Set 2 | hithadhoo
# Processing Record 13 of Set 2 | rock sound
# Processing Record 14 of Set 2 | bur gabo
# City not found. Skipping...
# Processing Record 15 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 16 of Set 2 | san luis
# Processing Record 17 of Set 2 | salym
# Processing Record 18 of Set 2 | grootfontein
# Processing Record 19 of Set 2 | kokstad
# Processing Record 20 of Set 2 | maniitsoq
# Processing Record 21 of Set 2 | salalah
# Processing Record 22 of Set 2 | canavieiras
# Processing Record 23 of Set 2 | east london
# Processing Record 24 of Set 2 | tarudant
# City not found. Skipping...
# Processing Record 25 of Set 2 | port alfred
# Processing Record 26 of Set 2 | santa barbara
# Processing Record 27 of Set 2 | laguna
# Processing Record 28 of Set 2 | kovdor
# Processing Record 29 of Set 2 | maralal
# Processing Record 30 of Set 2 | jacqueville
# Processing Record 31 of Set 2 | constitucion
# Processing Record 32 of Set 2 | manavgat
# Processing Record 33 of Set 2 | mariestad
# Processing Record 34 of Set 2 | qaanaaq
# Processing Record 35 of Set 2 | kutum
# Processing Record 36 of Set 2 | sisimiut
# Processing Record 37 of Set 2 | mitu
# Processing Record 38 of Set 2 | dingle
# Processing Record 39 of Set 2 | puerto narino
# Processing Record 40 of Set 2 | gat
# Processing Record 41 of Set 2 | eyl
# Processing Record 42 of Set 2 | bredasdorp
# Processing Record 43 of Set 2 | thompson
# Processing Record 44 of Set 2 | gazli
# Processing Record 45 of Set 2 | mao
# Processing Record 46 of Set 2 | buchanan
# Processing Record 47 of Set 2 | richards bay
# Processing Record 48 of Set 2 | bereda
# Processing Record 49 of Set 2 | uthal
# Processing Record 50 of Set 2 | jumla
# Processing Record 1 of Set 3 | sandwick
# Processing Record 2 of Set 3 | olafsvik
# Processing Record 3 of Set 3 | louisbourg
# City not found. Skipping...
# Processing Record 4 of Set 3 | sao filipe
# Processing Record 5 of Set 3 | valdivia
# Processing Record 6 of Set 3 | upernavik
# Processing Record 7 of Set 3 | mushie
# Processing Record 8 of Set 3 | naqadeh
# Processing Record 9 of Set 3 | kiruna
# Processing Record 10 of Set 3 | henties bay
# Processing Record 11 of Set 3 | mar del plata
# Processing Record 12 of Set 3 | necochea
# Processing Record 13 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 14 of Set 3 | buriti alegre
# Processing Record 15 of Set 3 | bonthe
# Processing Record 16 of Set 3 | meiganga
# Processing Record 17 of Set 3 | chimbote
# Processing Record 18 of Set 3 | quatre cocos
# Processing Record 19 of Set 3 | cap malheureux
# Processing Record 20 of Set 3 | kalaleh
# Processing Record 21 of Set 3 | francisco beltrao
# Processing Record 22 of Set 3 | punta arenas
# Processing Record 23 of Set 3 | la palma
# Processing Record 24 of Set 3 | nouakchott
# Processing Record 25 of Set 3 | mabaruma
# Processing Record 26 of Set 3 | galle
# Processing Record 27 of Set 3 | ribeira grande
# Processing Record 28 of Set 3 | cururupu
# Processing Record 29 of Set 3 | vila velha
# Processing Record 30 of Set 3 | porangatu
# Processing Record 31 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 32 of Set 3 | praia
# Processing Record 33 of Set 3 | naftah
# City not found. Skipping...
# Processing Record 34 of Set 3 | puerto leguizamo
# Processing Record 35 of Set 3 | bambous virieux
# Processing Record 36 of Set 3 | polovinnoye
# Processing Record 37 of Set 3 | cabinda
# Processing Record 38 of Set 3 | bom jardim
# Processing Record 39 of Set 3 | manali
# Processing Record 40 of Set 3 | polunochnoye
# Processing Record 41 of Set 3 | isilkul
# Processing Record 42 of Set 3 | bubaque
# Processing Record 43 of Set 3 | karlskrona
# Processing Record 44 of Set 3 | marawi
# Processing Record 45 of Set 3 | sarmanovo
# Processing Record 46 of Set 3 | lasa
# Processing Record 47 of Set 3 | krasnovishersk
# Processing Record 48 of Set 3 | okemos
# Processing Record 49 of Set 3 | baie-saint-paul
# Processing Record 50 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 1 of Set 4 | kudahuvadhoo
# Processing Record 2 of Set 4 | deh rawud
# City not found. Skipping...
# Processing Record 3 of Set 4 | zheleznodorozhnyy
# Processing Record 4 of Set 4 | motril
# Processing Record 5 of Set 4 | stralsund
# Processing Record 6 of Set 4 | sheksna
# Processing Record 7 of Set 4 | sinnamary
# Processing Record 8 of Set 4 | kanelovskaya
# Processing Record 9 of Set 4 | cayenne
# Processing Record 10 of Set 4 | zinder
# Processing Record 11 of Set 4 | saint george
# Processing Record 12 of Set 4 | menongue
# Processing Record 13 of Set 4 | los llanos de aridane
# Processing Record 14 of Set 4 | sheffield
# Processing Record 15 of Set 4 | husavik
# Processing Record 16 of Set 4 | tasiilaq
# Processing Record 17 of Set 4 | yataity del norte
# Processing Record 18 of Set 4 | saint anthony
# Processing Record 19 of Set 4 | ornskoldsvik
# Processing Record 20 of Set 4 | kishtwar
# Processing Record 21 of Set 4 | lokosovo
# Processing Record 22 of Set 4 | goias
# Processing Record 23 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 24 of Set 4 | rafsanjan
# Processing Record 25 of Set 4 | margate
# Processing Record 26 of Set 4 | luau
# Processing Record 27 of Set 4 | camana
# Processing Record 28 of Set 4 | sompeta
# Processing Record 29 of Set 4 | kruisfontein
# Processing Record 30 of Set 4 | georgiyevka
# Processing Record 31 of Set 4 | lebu
# Processing Record 32 of Set 4 | staritsa
# Processing Record 33 of Set 4 | bandarbeyla
# Processing Record 34 of Set 4 | quartucciu
# Processing Record 35 of Set 4 | sur
# Processing Record 36 of Set 4 | petrovsk
# Processing Record 37 of Set 4 | rio gallegos
# Processing Record 38 of Set 4 | axim
# Processing Record 39 of Set 4 | shahi
# Processing Record 40 of Set 4 | kochubey
# Processing Record 41 of Set 4 | san miguel
# Processing Record 42 of Set 4 | touros
# Processing Record 43 of Set 4 | portobelo
# Processing Record 44 of Set 4 | bengkulu
# Processing Record 45 of Set 4 | luderitz
# Processing Record 46 of Set 4 | kharp
# Processing Record 47 of Set 4 | laives
# Processing Record 48 of Set 4 | cariamanga
# Processing Record 49 of Set 4 | gurgan
# City not found. Skipping...
# Processing Record 50 of Set 4 | talnakh
# Processing Record 1 of Set 5 | otavi
# Processing Record 2 of Set 5 | kismayo
# Processing Record 3 of Set 5 | manfredonia
# Processing Record 4 of Set 5 | altonia
# City not found. Skipping...
# Processing Record 5 of Set 5 | fuerte olimpo
# Processing Record 6 of Set 5 | fonte boa
# Processing Record 7 of Set 5 | barra patuca
# Processing Record 8 of Set 5 | taltal
# Processing Record 9 of Set 5 | pangnirtung
# Processing Record 10 of Set 5 | barawe
# City not found. Skipping...
# Processing Record 11 of Set 5 | masyaf
# Processing Record 12 of Set 5 | mehran
# Processing Record 13 of Set 5 | lodwar
# Processing Record 14 of Set 5 | millau
# Processing Record 15 of Set 5 | nicoya
# Processing Record 16 of Set 5 | khorramshahr
# Processing Record 17 of Set 5 | kavaratti
# Processing Record 18 of Set 5 | teguldet
# Processing Record 19 of Set 5 | staryy nadym
# Processing Record 20 of Set 5 | vestmannaeyjar
# Processing Record 21 of Set 5 | codrington
# Processing Record 22 of Set 5 | igarka
# Processing Record 23 of Set 5 | mahalingpur
# Processing Record 24 of Set 5 | camapua
# Processing Record 25 of Set 5 | azimur
# City not found. Skipping...
# Processing Record 26 of Set 5 | hambantota
# Processing Record 27 of Set 5 | qaqortoq
# Processing Record 28 of Set 5 | clyde river
# Processing Record 29 of Set 5 | tiznit
# Processing Record 30 of Set 5 | kaka
# Processing Record 31 of Set 5 | sakakah
# Processing Record 32 of Set 5 | bordighera
# Processing Record 33 of Set 5 | porto-vecchio
# Processing Record 34 of Set 5 | sakaraha
# Processing Record 35 of Set 5 | longyearbyen
# Processing Record 36 of Set 5 | hamilton
# Processing Record 37 of Set 5 | namibe
# Processing Record 38 of Set 5 | shache
# Processing Record 39 of Set 5 | saint-augustin
# Processing Record 40 of Set 5 | zabid
# Processing Record 41 of Set 5 | watsa
# Processing Record 42 of Set 5 | jurado
# Processing Record 43 of Set 5 | camacha
# Processing Record 44 of Set 5 | praia da vitoria
# Processing Record 45 of Set 5 | nouadhibou
# Processing Record 46 of Set 5 | narsaq
# Processing Record 47 of Set 5 | kanniyakumari
# Processing Record 48 of Set 5 | turukhansk
# Processing Record 49 of Set 5 | pavlodar
# Processing Record 50 of Set 5 | sokoni
# Processing Record 1 of Set 6 | neyshabur
# Processing Record 2 of Set 6 | galatista
# Processing Record 3 of Set 6 | alta floresta
# Processing Record 4 of Set 6 | wadi musa
# Processing Record 5 of Set 6 | taoudenni
# Processing Record 6 of Set 6 | kjopsvik
# Processing Record 7 of Set 6 | leh
# Processing Record 8 of Set 6 | sistranda
# Processing Record 9 of Set 6 | tzaneen
# Processing Record 10 of Set 6 | polazna
# Processing Record 11 of Set 6 | andreapol
# Processing Record 12 of Set 6 | ati
# Processing Record 13 of Set 6 | abalak
# Processing Record 14 of Set 6 | mbandaka
# Processing Record 15 of Set 6 | marsaxlokk
# Processing Record 16 of Set 6 | taft
# Processing Record 17 of Set 6 | pauini
# Processing Record 18 of Set 6 | borama
# City not found. Skipping...
# Processing Record 19 of Set 6 | westport
# Processing Record 20 of Set 6 | buraydah
# Processing Record 21 of Set 6 | hun
# Processing Record 22 of Set 6 | marsh harbour
# Processing Record 23 of Set 6 | locri
# Processing Record 24 of Set 6 | wagar
# Processing Record 25 of Set 6 | santa isabel
# Processing Record 26 of Set 6 | adrar
# Processing Record 27 of Set 6 | chabahar
# Processing Record 28 of Set 6 | bayshore gardens
# Processing Record 29 of Set 6 | san rafael
# Processing Record 30 of Set 6 | paulo afonso
# Processing Record 31 of Set 6 | sinjar
# Processing Record 32 of Set 6 | mazyr
# Processing Record 33 of Set 6 | colesberg
# Processing Record 34 of Set 6 | sao jose da coroa grande
# Processing Record 35 of Set 6 | beruwala
# Processing Record 36 of Set 6 | lodja
# Processing Record 37 of Set 6 | parabel
# Processing Record 38 of Set 6 | mattru
# Processing Record 39 of Set 6 | les cayes
# Processing Record 40 of Set 6 | sayyan
# Processing Record 41 of Set 6 | ponta delgada
# Processing Record 42 of Set 6 | burica
# City not found. Skipping...
# Processing Record 43 of Set 6 | pasni
# Processing Record 44 of Set 6 | shieli
# Processing Record 45 of Set 6 | pinega
# Processing Record 46 of Set 6 | riccione
# Processing Record 47 of Set 6 | somerset
# Processing Record 48 of Set 6 | itarema
# Processing Record 49 of Set 6 | duz
# City not found. Skipping...
# Processing Record 50 of Set 6 | xuddur
# Processing Record 1 of Set 7 | modakeke
# Processing Record 2 of Set 7 | dzilam gonzalez
# Processing Record 3 of Set 7 | maceio
# Processing Record 4 of Set 7 | zanzibar
# Processing Record 5 of Set 7 | coihaique
# Processing Record 6 of Set 7 | upington
# Processing Record 7 of Set 7 | tombouctou
# Processing Record 8 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 9 of Set 7 | silopi
# Processing Record 10 of Set 7 | mangan
# Processing Record 11 of Set 7 | kralendijk
# Processing Record 12 of Set 7 | hobyo
# Processing Record 13 of Set 7 | caravelas
# Processing Record 14 of Set 7 | janesville
# Processing Record 15 of Set 7 | chalus
# Processing Record 16 of Set 7 | sfantu gheorghe
# Processing Record 17 of Set 7 | marsabit
# Processing Record 18 of Set 7 | baijiantan
# Processing Record 19 of Set 7 | oistins
# Processing Record 20 of Set 7 | morbach
# Processing Record 21 of Set 7 | bud
# Processing Record 22 of Set 7 | cabedelo
# Processing Record 23 of Set 7 | bonavista
# Processing Record 24 of Set 7 | mehamn
# Processing Record 25 of Set 7 | qandahar
# City not found. Skipping...
# Processing Record 26 of Set 7 | sept-iles
# Processing Record 27 of Set 7 | khandbari
# Processing Record 28 of Set 7 | yar-sale
# Processing Record 29 of Set 7 | saint-francois
# Processing Record 30 of Set 7 | totma
# Processing Record 31 of Set 7 | moshkovo
# Processing Record 32 of Set 7 | bella union
# Processing Record 33 of Set 7 | chandigarh
# Processing Record 34 of Set 7 | orumiyeh
# Processing Record 35 of Set 7 | alexandria
# Processing Record 36 of Set 7 | balykshi
# Processing Record 37 of Set 7 | yirol
# City not found. Skipping...
# Processing Record 38 of Set 7 | tabou
# Processing Record 39 of Set 7 | phalaborwa
# Processing Record 40 of Set 7 | novovarshavka
# Processing Record 41 of Set 7 | road town
# Processing Record 42 of Set 7 | oia
# Processing Record 43 of Set 7 | ostrogozhsk
# Processing Record 44 of Set 7 | manta
# Processing Record 45 of Set 7 | tessalit
# Processing Record 46 of Set 7 | rabo de peixe
# Processing Record 47 of Set 7 | plouzane
# Processing Record 48 of Set 7 | jizan
# Processing Record 49 of Set 7 | kavadarci
# Processing Record 50 of Set 7 | muros
# Processing Record 1 of Set 8 | harper
# Processing Record 2 of Set 8 | ilhabela
# Processing Record 3 of Set 8 | port shepstone
# Processing Record 4 of Set 8 | padang
# Processing Record 5 of Set 8 | severodvinsk
# Processing Record 6 of Set 8 | robertsport
# Processing Record 7 of Set 8 | povoa de varzim
# Processing Record 8 of Set 8 | bukama
# Processing Record 9 of Set 8 | asfi
# Processing Record 10 of Set 8 | cockburn town
# Processing Record 11 of Set 8 | bay roberts
# Processing Record 12 of Set 8 | kisesa
# Processing Record 13 of Set 8 | staunton
# Processing Record 14 of Set 8 | horni plana
# Processing Record 15 of Set 8 | kontagora
# Processing Record 16 of Set 8 | isiro
# Processing Record 17 of Set 8 | nantucket
# Processing Record 18 of Set 8 | muzaffargarh
# Processing Record 19 of Set 8 | appleton
# Processing Record 20 of Set 8 | nueve de julio
# Processing Record 21 of Set 8 | mercedes
# Processing Record 22 of Set 8 | tekkali
# Processing Record 23 of Set 8 | yenagoa
# Processing Record 24 of Set 8 | yurgamysh
# Processing Record 25 of Set 8 | faya
# Processing Record 26 of Set 8 | murdochville
# Processing Record 27 of Set 8 | gao
# Processing Record 28 of Set 8 | bridlington
# Processing Record 29 of Set 8 | srivardhan
# Processing Record 30 of Set 8 | nola
# Processing Record 31 of Set 8 | south shields
# Processing Record 32 of Set 8 | znamenskoye
# Processing Record 33 of Set 8 | bulawayo
# Processing Record 34 of Set 8 | nynashamn
# Processing Record 35 of Set 8 | rio grande
# Processing Record 36 of Set 8 | bucyrus
# Processing Record 37 of Set 8 | larsnes
# Processing Record 38 of Set 8 | madimba
# Processing Record 39 of Set 8 | santa cruz
# Processing Record 40 of Set 8 | barkot
# Processing Record 41 of Set 8 | borovskoy
# Processing Record 42 of Set 8 | ust-tsilma
# Processing Record 43 of Set 8 | kokkola
# Processing Record 44 of Set 8 | sao francisco de assis
# Processing Record 45 of Set 8 | ponnani
# Processing Record 46 of Set 8 | jilib
# Processing Record 47 of Set 8 | korla
# Processing Record 48 of Set 8 | attawapiskat
# City not found. Skipping...
# Processing Record 49 of Set 8 | mogadishu
# Processing Record 50 of Set 8 | belmonte
# Processing Record 1 of Set 9 | san juan de los morros
# Processing Record 2 of Set 9 | colares
# Processing Record 3 of Set 9 | jalu
# Processing Record 4 of Set 9 | banda aceh
# Processing Record 5 of Set 9 | semnan
# Processing Record 6 of Set 9 | antalaha
# Processing Record 7 of Set 9 | aragarcas
# Processing Record 8 of Set 9 | kuche
# City not found. Skipping...
# Processing Record 9 of Set 9 | tikapur
# Processing Record 10 of Set 9 | hatillo
# Processing Record 11 of Set 9 | viedma
# Processing Record 12 of Set 9 | baudh
# Processing Record 13 of Set 9 | navrongo
# Processing Record 14 of Set 9 | brae
# Processing Record 15 of Set 9 | puerto ayacucho
# Processing Record 16 of Set 9 | maykor
# Processing Record 17 of Set 9 | mitsamiouli
# Processing Record 18 of Set 9 | skibbereen
# Processing Record 19 of Set 9 | the valley
# Processing Record 20 of Set 9 | thohoyandou
# Processing Record 21 of Set 9 | ostrovnoy
# Processing Record 22 of Set 9 | karabuk
# Processing Record 23 of Set 9 | mizan teferi
# Processing Record 24 of Set 9 | challapata
# Processing Record 25 of Set 9 | jaisinghnagar
# Processing Record 26 of Set 9 | chadiza
# Processing Record 27 of Set 9 | bathsheba
# Processing Record 28 of Set 9 | tasbuget
# City not found. Skipping...
# Processing Record 29 of Set 9 | gouyave
# Processing Record 30 of Set 9 | ancud
# Processing Record 31 of Set 9 | aktash
# Processing Record 32 of Set 9 | panjakent
# Processing Record 33 of Set 9 | awjilah
# Processing Record 34 of Set 9 | nguruka
# Processing Record 35 of Set 9 | saint-pierre
# Processing Record 36 of Set 9 | senneterre
# Processing Record 37 of Set 9 | hofn
# Processing Record 38 of Set 9 | loukhi
# Processing Record 39 of Set 9 | slavutych
# Processing Record 40 of Set 9 | palmares do sul
# Processing Record 41 of Set 9 | ilheus
# Processing Record 42 of Set 9 | obo
# Processing Record 43 of Set 9 | aswan
# Processing Record 44 of Set 9 | porto belo
# Processing Record 45 of Set 9 | marrakesh
# Processing Record 46 of Set 9 | chongwe
# Processing Record 47 of Set 9 | kill
# Processing Record 48 of Set 9 | qeshm
# Processing Record 49 of Set 9 | barra
# Processing Record 50 of Set 9 | harur
# Processing Record 1 of Set 10 | itigi
# Processing Record 2 of Set 10 | port blair
# Processing Record 3 of Set 10 | acarau
# Processing Record 4 of Set 10 | basoko
# Processing Record 5 of Set 10 | salekhard
# Processing Record 6 of Set 10 | abu samrah
# Processing Record 7 of Set 10 | pitimbu
# Processing Record 8 of Set 10 | carnarvon
# Processing Record 9 of Set 10 | kafanchan
# Processing Record 10 of Set 10 | onega
# Processing Record 11 of Set 10 | nagapattinam
# Processing Record 12 of Set 10 | abha
# Processing Record 13 of Set 10 | naryan-mar
# Processing Record 14 of Set 10 | banepa
# Processing Record 15 of Set 10 | yei
# Processing Record 16 of Set 10 | carahue
# Processing Record 17 of Set 10 | takoradi
# Processing Record 18 of Set 10 | kananga
# Processing Record 19 of Set 10 | leshukonskoye
# Processing Record 20 of Set 10 | krasnoarmeyskiy
# Processing Record 21 of Set 10 | nokia
# Processing Record 22 of Set 10 | juba
# Processing Record 23 of Set 10 | muscat
# Processing Record 24 of Set 10 | krasnoselkup
# Processing Record 25 of Set 10 | areosa
# Processing Record 26 of Set 10 | caceres
# Processing Record 27 of Set 10 | monrovia
# Processing Record 28 of Set 10 | port-gentil
# Processing Record 29 of Set 10 | angoche
# Processing Record 30 of Set 10 | dusnok
# Processing Record 31 of Set 10 | skalistyy
# City not found. Skipping...
# Processing Record 32 of Set 10 | carbonia
# Processing Record 33 of Set 10 | gaspe
# Processing Record 34 of Set 10 | arlit
# Processing Record 35 of Set 10 | karpathos
# Processing Record 36 of Set 10 | birjand
# Processing Record 37 of Set 10 | tanout
# Processing Record 38 of Set 10 | sainte-marie
# Processing Record 39 of Set 10 | parrsboro
# Processing Record 40 of Set 10 | pangoa
# Processing Record 41 of Set 10 | cockburn harbour
# City not found. Skipping...
# Processing Record 42 of Set 10 | mamlyutka
# Processing Record 43 of Set 10 | paamiut
# Processing Record 44 of Set 10 | pirenopolis
# Processing Record 45 of Set 10 | grahamstown
# Processing Record 46 of Set 10 | toktogul
# Processing Record 47 of Set 10 | yining
# Processing Record 48 of Set 10 | oktyabrskiy
# Processing Record 49 of Set 10 | aliaga
# Processing Record 50 of Set 10 | talcahuano
# Processing Record 1 of Set 11 | grand-santi
# Processing Record 2 of Set 11 | snezhnogorsk
# Processing Record 3 of Set 11 | liepaja
# Processing Record 4 of Set 11 | nador
# Processing Record 5 of Set 11 | masjed-e soleyman
# City not found. Skipping...
# Processing Record 6 of Set 11 | berea
# Processing Record 7 of Set 11 | khorixas
# Processing Record 8 of Set 11 | paita
# Processing Record 9 of Set 11 | sinkat
# City not found. Skipping...
# Processing Record 10 of Set 11 | bandundu
# Processing Record 11 of Set 11 | pemba
# Processing Record 12 of Set 11 | acopiara
# Processing Record 13 of Set 11 | bhinmal
# Processing Record 14 of Set 11 | kamenka
# Processing Record 15 of Set 11 | timmins
# Processing Record 16 of Set 11 | caibarien
# Processing Record 17 of Set 11 | felanitx
# Processing Record 18 of Set 11 | shepsi
# Processing Record 19 of Set 11 | nirmal
# Processing Record 20 of Set 11 | somers
# Processing Record 21 of Set 11 | matara
# Processing Record 22 of Set 11 | olinda
# Processing Record 23 of Set 11 | aksu
# Processing Record 24 of Set 11 | aljezur
# Processing Record 25 of Set 11 | mocuba
# Processing Record 26 of Set 11 | manoel urbano
# Processing Record 27 of Set 11 | pisco
# Processing Record 28 of Set 11 | ivaipora
# Processing Record 29 of Set 11 | luanda
# Processing Record 30 of Set 11 | ngama
# Processing Record 31 of Set 11 | los andes
# Processing Record 32 of Set 11 | concepcion del uruguay
# Processing Record 33 of Set 11 | mandera
# Processing Record 34 of Set 11 | mpulungu
# Processing Record 35 of Set 11 | buta
# Processing Record 36 of Set 11 | atar
# Processing Record 37 of Set 11 | thinadhoo
# Processing Record 38 of Set 11 | manaure
# Processing Record 39 of Set 11 | san andres
# Processing Record 40 of Set 11 | lemesos
# City not found. Skipping...
# Processing Record 41 of Set 11 | porto novo
# Processing Record 42 of Set 11 | karaul
# City not found. Skipping...
# Processing Record 43 of Set 11 | toliary
# City not found. Skipping...
# Processing Record 44 of Set 11 | havre-saint-pierre
# Processing Record 45 of Set 11 | filadelfia
# Processing Record 46 of Set 11 | sundsvall
# Processing Record 47 of Set 11 | kalemie
# Processing Record 48 of Set 11 | promyshlennaya
# Processing Record 49 of Set 11 | dawlatabad
# Processing Record 50 of Set 11 | barranca
# Processing Record 1 of Set 12 | rozhyshche
# Processing Record 2 of Set 12 | ochamchira
# Processing Record 3 of Set 12 | bokspits
# City not found. Skipping...
# Processing Record 4 of Set 12 | mvuma
# Processing Record 5 of Set 12 | aleksandrow kujawski
# Processing Record 6 of Set 12 | floro
# Processing Record 7 of Set 12 | ngerengere
# Processing Record 8 of Set 12 | moose factory
# Processing Record 9 of Set 12 | pyaozerskiy
# Processing Record 10 of Set 12 | zlobin
# Processing Record 11 of Set 12 | san matias
# Processing Record 12 of Set 12 | chute-aux-outardes
# Processing Record 13 of Set 12 | mana
# Processing Record 14 of Set 12 | riachao
# Processing Record 15 of Set 12 | urucara
# Processing Record 16 of Set 12 | santiago de chuco
# Processing Record 17 of Set 12 | antsohihy
# Processing Record 18 of Set 12 | skoczow
# Processing Record 19 of Set 12 | halifax
# Processing Record 20 of Set 12 | berlevag
# Processing Record 21 of Set 12 | cossato
# Processing Record 22 of Set 12 | stokmarknes
# Processing Record 23 of Set 12 | punta de bombon
# Processing Record 24 of Set 12 | iracoubo
# Processing Record 25 of Set 12 | qiryat shemona
# Processing Record 26 of Set 12 | susehri
# Processing Record 27 of Set 12 | paramonga
# Processing Record 28 of Set 12 | mangaratiba
# Processing Record 29 of Set 12 | santa rosa
# Processing Record 30 of Set 12 | buenos aires
# Processing Record 31 of Set 12 | buncrana
# Processing Record 32 of Set 12 | tigre
# Processing Record 33 of Set 12 | abu dhabi
# Processing Record 34 of Set 12 | south river
# Processing Record 35 of Set 12 | khetia
# Processing Record 36 of Set 12 | coracora
# Processing Record 37 of Set 12 | mali
# Processing Record 38 of Set 12 | dunda
# Processing Record 39 of Set 12 | morant bay
# Processing Record 40 of Set 12 | maragogi
# Processing Record 41 of Set 12 | tinqueux
# Processing Record 42 of Set 12 | santa luzia
# Processing Record 43 of Set 12 | urdzhar
# City not found. Skipping...
# Processing Record 44 of Set 12 | am timan
# Processing Record 45 of Set 12 | mwense
# Processing Record 46 of Set 12 | saint augustine
# Processing Record 47 of Set 12 | dudinka
# Processing Record 48 of Set 12 | gewane
# Processing Record 49 of Set 12 | rorvik
# Processing Record 50 of Set 12 | vryburg
# Processing Record 1 of Set 13 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 2 of Set 13 | maxixe
# Processing Record 3 of Set 13 | port said
# Processing Record 4 of Set 13 | mosterhamn
# Processing Record 5 of Set 13 | trairi
# Processing Record 6 of Set 13 | songea
# Processing Record 7 of Set 13 | sines
# Processing Record 8 of Set 13 | charlottesville
# Processing Record 9 of Set 13 | ambodifototra
# City not found. Skipping...
# Processing Record 10 of Set 13 | fereydun kenar
# Processing Record 11 of Set 13 | mathathane
# Processing Record 12 of Set 13 | aranos
# Processing Record 13 of Set 13 | shenkursk
# Processing Record 14 of Set 13 | aravankadu
# Processing Record 15 of Set 13 | santa isabel do rio negro
# Processing Record 16 of Set 13 | pereslavl-zalesskiy
# Processing Record 17 of Set 13 | santa maria
# Processing Record 18 of Set 13 | catumbela
# Processing Record 19 of Set 13 | umm lajj
# Processing Record 20 of Set 13 | birao
# Processing Record 21 of Set 13 | inyonga
# Processing Record 22 of Set 13 | walvis bay
# Processing Record 23 of Set 13 | bluefield
# Processing Record 24 of Set 13 | youkounkoun
# Processing Record 25 of Set 13 | sabirabad
# Processing Record 26 of Set 13 | surovikino
# Processing Record 27 of Set 13 | nuuk
# Processing Record 28 of Set 13 | morondava
# Processing Record 29 of Set 13 | cambridge
# Processing Record 30 of Set 13 | formoso do araguaia
# City not found. Skipping...
# Processing Record 31 of Set 13 | coruripe
# Processing Record 32 of Set 13 | santa cruz cabralia
# Processing Record 33 of Set 13 | sao joao da barra
# Processing Record 34 of Set 13 | uglich
# Processing Record 35 of Set 13 | tocopilla
# Processing Record 36 of Set 13 | bindura
# Processing Record 37 of Set 13 | presidencia roque saenz pena
# Processing Record 38 of Set 13 | qunduz
# Processing Record 39 of Set 13 | kasongo-lunda
# Processing Record 40 of Set 13 | wallasey
# Processing Record 41 of Set 13 | reims
# Processing Record 42 of Set 13 | areia branca
# Processing Record 43 of Set 13 | mahaicony
# City not found. Skipping...
# Processing Record 44 of Set 13 | kristiansund
# Processing Record 45 of Set 13 | zolotkovo
# Processing Record 46 of Set 13 | foumbot
# Processing Record 47 of Set 13 | tazovskiy
# Processing Record 48 of Set 13 | ugoofaaru
# Processing Record 49 of Set 13 | carballo
# Processing Record 50 of Set 13 | pocone
# Processing Record 1 of Set 14 | porto san giorgio
# Processing Record 2 of Set 14 | nacala
# Processing Record 3 of Set 14 | horki
# Processing Record 4 of Set 14 | bajil
# Processing Record 5 of Set 14 | kamarion
# Processing Record 6 of Set 14 | girne
# Processing Record 7 of Set 14 | mezen
# Processing Record 8 of Set 14 | troitsko-pechorsk
# Processing Record 9 of Set 14 | teguise
# Processing Record 10 of Set 14 | kollumerland
# City not found. Skipping...
# Processing Record 11 of Set 14 | lahij
# Processing Record 12 of Set 14 | port victoria
# Processing Record 13 of Set 14 | valparaiso
# Processing Record 14 of Set 14 | skagastrond
# City not found. Skipping...
# Processing Record 15 of Set 14 | saint-georges
# Processing Record 16 of Set 14 | marsa matruh
# Processing Record 17 of Set 14 | warqla
# City not found. Skipping...
# Processing Record 18 of Set 14 | sao gabriel da cachoeira
# Processing Record 19 of Set 14 | asosa
# Processing Record 20 of Set 14 | saryshagan
# City not found. Skipping...
# Processing Record 21 of Set 14 | zhezkazgan
# Processing Record 22 of Set 14 | bababe
# City not found. Skipping...
# Processing Record 23 of Set 14 | clacton-on-sea
# Processing Record 24 of Set 14 | tawnat
# City not found. Skipping...
# Processing Record 25 of Set 14 | kilindoni
# Processing Record 26 of Set 14 | rawson
# Processing Record 27 of Set 14 | ormond beach
# Processing Record 28 of Set 14 | buritis
# Processing Record 29 of Set 14 | solsvik
# City not found. Skipping...
# Processing Record 30 of Set 14 | sinazongwe
# Processing Record 31 of Set 14 | puerto carreno
# Processing Record 32 of Set 14 | iquique
# Processing Record 33 of Set 14 | porto seguro
# Processing Record 34 of Set 14 | brasilia
# Processing Record 35 of Set 14 | pailitas
# Processing Record 36 of Set 14 | la rioja
# Processing Record 37 of Set 14 | tignere
# Processing Record 38 of Set 14 | uray
# Processing Record 39 of Set 14 | jonkoping
# Processing Record 40 of Set 14 | palafrugell
# Processing Record 41 of Set 14 | monte cristi
# City not found. Skipping...
# Processing Record 42 of Set 14 | melfi
# Processing Record 43 of Set 14 | piranshahr
# Processing Record 44 of Set 14 | soanierana ivongo
# Processing Record 45 of Set 14 | jaru
# Processing Record 46 of Set 14 | maloy
# Processing Record 47 of Set 14 | muisne
# Processing Record 48 of Set 14 | shahreza
# Processing Record 49 of Set 14 | sorland
# Processing Record 50 of Set 14 | westpunt
# City not found. Skipping...
# Processing Record 1 of Set 15 | garmsar
# Processing Record 2 of Set 15 | brigantine
# Processing Record 3 of Set 15 | ambilobe
# Processing Record 4 of Set 15 | bumba
# Processing Record 5 of Set 15 | galgani
# City not found. Skipping...
# Processing Record 6 of Set 15 | letterkenny
# Processing Record 7 of Set 15 | hauterive
# Processing Record 8 of Set 15 | chitral
# Processing Record 9 of Set 15 | dire
# Processing Record 10 of Set 15 | south venice
# Processing Record 11 of Set 15 | becerril
# Processing Record 12 of Set 15 | campoverde
# Processing Record 13 of Set 15 | bagaciu
# Processing Record 14 of Set 15 | rundu
# Processing Record 15 of Set 15 | visnes
# Processing Record 16 of Set 15 | kishi
# Processing Record 17 of Set 15 | piombino
# Processing Record 18 of Set 15 | saint andrews
# Processing Record 19 of Set 15 | oranjemund
# Processing Record 20 of Set 15 | omboue
# Processing Record 21 of Set 15 | grindavik
# Processing Record 22 of Set 15 | higuey
# City not found. Skipping...
# Processing Record 23 of Set 15 | mukhtolovo
# Processing Record 24 of Set 15 | horw
# Processing Record 25 of Set 15 | nosy varika
# Processing Record 26 of Set 15 | azul
# Processing Record 27 of Set 15 | new richmond
# Processing Record 28 of Set 15 | shelburne
# Processing Record 29 of Set 15 | nchelenge
# Processing Record 30 of Set 15 | illela
# Processing Record 31 of Set 15 | kasane
# Processing Record 32 of Set 15 | parrita
# Processing Record 33 of Set 15 | ossipee
# Processing Record 34 of Set 15 | bosaso
# Processing Record 35 of Set 15 | severnyy
# Processing Record 36 of Set 15 | peyima
# Processing Record 37 of Set 15 | carbondale
# Processing Record 38 of Set 15 | januaria
# Processing Record 39 of Set 15 | kyrnasivka
# Processing Record 40 of Set 15 | cherepanovo
# Processing Record 41 of Set 15 | awbari
# Processing Record 42 of Set 15 | sao lourenco do sul
# Processing Record 43 of Set 15 | benghazi
# Processing Record 44 of Set 15 | podgornoye
# Processing Record 45 of Set 15 | freistadt
# Processing Record 46 of Set 15 | sao miguel do araguaia
# Processing Record 47 of Set 15 | krasnoshchekovo
# Processing Record 48 of Set 15 | norrkoping
# Processing Record 49 of Set 15 | ladario
# Processing Record 50 of Set 15 | cheuskiny
# City not found. Skipping...
# Processing Record 1 of Set 16 | karaton
# Processing Record 2 of Set 16 | macaubas
# Processing Record 3 of Set 16 | wladyslawowo
# Processing Record 4 of Set 16 | limon
# Processing Record 5 of Set 16 | rio tercero
# Processing Record 6 of Set 16 | beloha
# Processing Record 7 of Set 16 | occhiobello
# Processing Record 8 of Set 16 | vigrestad
# Processing Record 9 of Set 16 | ituni
# City not found. Skipping...
# Processing Record 10 of Set 16 | vigeland
# Processing Record 11 of Set 16 | bithur
# Processing Record 12 of Set 16 | mulchen
# Processing Record 13 of Set 16 | araouane
# Processing Record 14 of Set 16 | barcelos
# Processing Record 15 of Set 16 | soltsy
# Processing Record 16 of Set 16 | charyshskoye
# Processing Record 17 of Set 16 | caernarfon
# Processing Record 18 of Set 16 | cacoal
# Processing Record 19 of Set 16 | kurchum
# Processing Record 20 of Set 16 | hammerfest
# Processing Record 21 of Set 16 | mikhaylovka
# Processing Record 22 of Set 16 | cape coast
# Processing Record 23 of Set 16 | albany
# Processing Record 24 of Set 16 | general jose eduvigis diaz
# Processing Record 25 of Set 16 | itaocara
# -----------------------
# Data Retrieval Complete
# -----------------------

# %%
len(city_data)
# Out:
# 721

# %%
# Convert array into a pandas DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                    City Country      Lat      Lng  Max Temp  Humidity  \
# 0                 Vardo      NO  70.3705  31.1107     37.38       100
# 1                Torbay      CA  47.6666 -52.7314     47.17        57
# 2        Saint-Philippe      RE -21.3585  55.7679     71.19        78
# 3               Pachino      IT  36.7186  15.0907     60.26        67
# 4  Vila Franca Do Campo      PT  37.7167 -25.4333     66.20        92
# 5              Saldanha      ZA -33.0117  17.9442     55.45        94
# 6              Hermanus      ZA -34.4187  19.2345     61.81        81
# 7               Papayal      PE  -4.0761 -80.7361     72.30        87
# 8                 Sayat      TM  38.7839  63.8803     58.87        31
# 9                  Myre      NO  69.1036  15.9492     43.34        92
#
#    Cloudiness  Wind Speed      Description
# 0         100       12.66  overcast clouds
# 1          20       18.41       few clouds
# 2           5        4.79        clear sky
# 3           0        3.02        clear sky
# 4         100        3.96  overcast clouds
# 5          77        1.57    broken clouds
# 6         100       15.01  overcast clouds
# 7          98        2.86  overcast clouds
# 8          15       11.65       few clouds
# 9         100        9.84       light rain

# %%
# Create output file (csv)
output_data_file = "WeatherPy_Database.csv"

# Export city_data_df into a CSV
city_data_df.to_csv(output_data_file, index_label="City_ID")
